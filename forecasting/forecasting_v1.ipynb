# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('/home/ic-unicamp/Documentos/Estudo/Projects/forecasting/data/train.csv')
test = pd.read_csv('/home/ic-unicamp/Documentos/Estudo/Projects/forecasting/data/test.csv')

# %%
train = train.rename_axis('id').reset_index()

# %%
train.head()
# Out:
#    id        date  store  item  sales
# 0   0  2013-01-01      1     1     13
# 1   1  2013-01-02      1     1     11
# 2   2  2013-01-03      1     1     14
# 3   3  2013-01-04      1     1     13
# 4   4  2013-01-05      1     1     10

# %%
test.head()
# Out:
#    id        date  store  item
# 0   0  2018-01-01      1     1
# 1   1  2018-01-02      1     1
# 2   2  2018-01-03      1     1
# 3   3  2018-01-04      1     1
# 4   4  2018-01-05      1     1

# %%
train.loc[(train['store'] == 2) & (train['item'] == 1) & (train['date'] < '2015-01-21')].plot(x = 'date', y = 'sales', figsize=(20,10))

plt.show()

# %%
variables = ['date', 'store']

X = train[variables]
y = train['sales']
